# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
import os

PATIENT_ID = "person_id"

# ------------------------------------------------
# FILES FOR EACH TIME WINDOW
# ------------------------------------------------
files = {
    "0_6":   "patients_0_6hrs.parquet",
    "6_12":  "patients_6_12hrs.parquet",
    "12_18": "patients_12_18hrs.parquet",
    "18_24": "patients_18_24hrs.parquet",
    "24_30": "patients_24_30hrs.parquet",
    "30_36": "patients_30_36hrs.parquet",
    "36_42": "patients_36_42hrs.parquet",
    "42_48": "patients_42_48hrs.parquet",
    "48_54": "patients_48_54hrs.parquet",
    "54_60": "patients_54_60hrs.parquet",
    "60_66": "patients_60_66hrs.parquet",
    "66_72": "patients_66_72hrs.parquet"
}

# ------------------------------------------------
# PHYSIOLOGICALLY PLAUSIBLE RANGES
# ------------------------------------------------
PLAUSIBLE_RANGES = {
    "fio2_mean": (21, 100),
    "peep_mean": (3, 25),
    "peak_mean": (10, 50),
    "pao2_mean": (50, 500),
    "spo2_mean": (70, 100),
    "ph_mean": (7.0, 7.6),
    "crp_mean": (0, 400),
    "wbc_mean": (1, 50),
    "temp_mean": (35, 42),
    "map_mean": (50, 120),
    "sbp_mean": (70, 200),
    "dbp_mean": (40, 120),
    "creatinine_mean": (20, 800),
    "platelets_mean": (20, 800),
    "age": (18, 100)
}

# ------------------------------------------------
# STORAGE
# ------------------------------------------------
patient_level_results = {}
phenotype_summaries = {}
data_quality_summary = []

# Create output directories
os.makedirs("phenotype_summaries", exist_ok=True)
os.makedirs("phenotype_plots", exist_ok=True)

# Color palette
palette = {0: "#1f77b4", 1: "#d62728"}

# ============================================================
# LOOP OVER TIME WINDOWS
# ============================================================
for window, path in files.items():

    print(f"\n{'='*60}")
    print(f"Processing window: {window} hrs")
    print(f"{'='*60}")

    # LOAD DATA
    if path.endswith(".parquet"):
        df = pd.read_parquet(path)
    else:
        df = pd.read_csv(path)
    
    n_rows_original = len(df)
    n_patients_original = df[PATIENT_ID].nunique()
    print(f"Original data: {n_rows_original} rows, {n_patients_original} patients")

    # FILTER OUT ABNORMAL VALUES
    df_clean = df.copy()
    
    for col, (low, high) in PLAUSIBLE_RANGES.items():
        if col in df_clean.columns:
            df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')
            mask = (df_clean[col].notna()) & ((df_clean[col] < low) | (df_clean[col] > high))
            n_filtered = mask.sum()
            df_clean = df_clean[~mask]
            if n_filtered > 0:
                print(f"  Filtered {n_filtered} rows with abnormal {col} values")
    
    n_rows_clean = len(df_clean)
    n_patients_clean = df_clean[PATIENT_ID].nunique()
    print(f"After filtering: {n_rows_clean} rows ({100*n_rows_clean/n_rows_original:.1f}%), {n_patients_clean} patients")
    
    data_quality_summary.append({
        'window': window,
        'original_rows': n_rows_original,
        'clean_rows': n_rows_clean,
        'rows_removed': n_rows_original - n_rows_clean,
        'original_patients': n_patients_original,
        'clean_patients': n_patients_clean,
        'patients_removed': n_patients_original - n_patients_clean
    })

    # AGGREGATION RULES
    AGG_RULES = {
        "fio2_mean": "max",
        "peep_mean": "max",
        "peak_mean": "max",
        "pao2_mean": "min",
        "spo2_mean": "min",
        "ph_mean": "min",
        "crp_mean": "max",
        "wbc_mean": "max",
        "temp_mean": "max",
        "map_mean": "min",
        "sbp_mean": "min",
        "dbp_mean": "min",
        "creatinine_mean": "max",
        "platelets_mean": "min",
        "age": "first"
    }
    AGG_RULES = {k: v for k, v in AGG_RULES.items() if k in df_clean.columns}

    # AGGREGATE TO PATIENT LEVEL
    df_patient = df_clean.groupby(PATIENT_ID, as_index=False).agg(AGG_RULES)
    print(f"Patient-level data: {len(df_patient)} patients")

    # PREPARE FEATURES FOR CLUSTERING
    X = df_patient[list(AGG_RULES.keys())].apply(pd.to_numeric, errors="coerce")
    missing_before_imputation = X.isna().sum().sum()
    if missing_before_imputation > 0:
        print(f"Missing values before imputation: {missing_before_imputation}")
        X = X.fillna(X.mean())
    
    assert X.isna().sum().sum() == 0, "Still have missing values after imputation!"

    if len(df_patient) < 10:
        print(f"WARNING: Only {len(df_patient)} patients - skipping clustering")
        continue

    # STANDARDIZE
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # GMM PHENOTYPING
    gmm = GaussianMixture(
        n_components=2,
        covariance_type="full",
        random_state=42,
        n_init=10
    )
    df_patient["icu_phenotype"] = gmm.fit_predict(X_scaled)
    
    phenotype_counts = df_patient["icu_phenotype"].value_counts().sort_index()
    print(f"\nPhenotype distribution:")
    for pheno, count in phenotype_counts.items():
        print(f"  Phenotype {pheno}: {count} patients ({100*count/len(df_patient):.1f}%)")

    # PHENOTYPE SUMMARY
    phenotype_summary = (
        df_patient
        .groupby("icu_phenotype")[X.columns]
        .mean()
        .T
    )

    # STORE RESULTS
    patient_level_results[window] = df_patient
    phenotype_summaries[window] = phenotype_summary
    
    # Save summary CSV
    csv_filename = f"phenotype_summaries/phenotype_summary_{window}hrs.csv"
    phenotype_summary.to_csv(csv_filename)
    print(f"Saved summary to: {csv_filename}")

    # ============================================================
    # CREATE PCA CLUSTER PLOT
    # ============================================================
    pca = PCA(n_components=2, random_state=42)
    X_pca = pca.fit_transform(X_scaled)
    
    df_plot = df_patient.copy()
    df_plot["PC1"] = X_pca[:, 0]
    df_plot["PC2"] = X_pca[:, 1]
    
    # Create plot
    sns.set_style("whitegrid")
    fig, ax = plt.subplots(figsize=(10, 7))
    
    sns.scatterplot(
        data=df_plot,
        x="PC1",
        y="PC2",
        hue="icu_phenotype",
        palette=palette,
        s=80,
        alpha=0.75,
        edgecolor="black",
        linewidth=0.5,
        ax=ax
    )
    
    # Title with patient counts
    title = f"GMM ICU Phenotypes: {window} Hours\n"
    title += f"Phenotype 0: n={phenotype_counts.get(0, 0):,} | Phenotype 1: n={phenotype_counts.get(1, 0):,}"
    
    ax.set_title(title, fontsize=14, weight="bold", pad=20)
    ax.set_xlabel(
        f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)",
        fontsize=12
    )
    ax.set_ylabel(
        f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)",
        fontsize=12
    )
    ax.legend(
        title="Phenotype",
        title_fontsize=11,
        fontsize=10,
        frameon=True,
        loc='best'
    )
    
    plt.tight_layout()
    plot_filename = f"phenotype_plots/cluster_plot_{window}hrs.png"
    plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
    print(f"Saved plot to: {plot_filename}")
    plt.close()

    print("\nPhenotype Summary:")
    print(phenotype_summary)

# ============================================================
# SAVE DATA QUALITY SUMMARY
# ============================================================
quality_df = pd.DataFrame(data_quality_summary)
quality_df.to_csv("phenotype_summaries/data_quality_summary.csv", index=False)
print(f"\n{'='*60}")
print("Data quality summary saved to: phenotype_summaries/data_quality_summary.csv")

# ============================================================
# SAVE ALL PHENOTYPE SUMMARIES IN ONE FILE
# ============================================================
all_summaries = []
for window, summary in phenotype_summaries.items():
    summary_with_window = summary.copy()
    summary_with_window.insert(0, 'time_window', window)
    summary_with_window['variable'] = summary_with_window.index
    all_summaries.append(summary_with_window)

if all_summaries:
    combined_df = pd.concat(all_summaries, ignore_index=False)
    combined_df.to_csv("phenotype_summaries/all_phenotypes_combined.csv")
    print("Combined summary saved to: phenotype_summaries/all_phenotypes_combined.csv")

# ============================================================
# CREATE COMBINED PLOT (ALL WINDOWS)
# ============================================================
print("\nCreating combined plot with all time windows...")

n_windows = len(patient_level_results)
n_cols = 4
n_rows = (n_windows + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5*n_rows))
axes = axes.flatten()

sns.set_style("whitegrid")

for idx, (window, df_patient) in enumerate(sorted(patient_level_results.items())):
    ax = axes[idx]
    
    # Get features
    FEATURE_COLS = [
        c for c in df_patient.columns
        if c not in [PATIENT_ID, "icu_phenotype", "PC1", "PC2"]
    ]
    
    X = df_patient[FEATURE_COLS].apply(pd.to_numeric, errors="coerce")
    X = X.fillna(X.mean())
    X_scaled = StandardScaler().fit_transform(X)
    
    # PCA
    pca = PCA(n_components=2, random_state=42)
    X_pca = pca.fit_transform(X_scaled)
    
    df_plot = df_patient.copy()
    df_plot["PC1"] = X_pca[:, 0]
    df_plot["PC2"] = X_pca[:, 1]
    
    phenotype_counts = df_plot["icu_phenotype"].value_counts().sort_index()
    
    # Plot
    for phenotype in sorted(df_plot["icu_phenotype"].unique()):
        mask = df_plot["icu_phenotype"] == phenotype
        ax.scatter(
            df_plot.loc[mask, "PC1"],
            df_plot.loc[mask, "PC2"],
            c=palette[phenotype],
            s=30,
            alpha=0.6,
            edgecolor="black",
            linewidth=0.3,
            label=f"Pheno {phenotype} (n={phenotype_counts.get(phenotype, 0):,})"
        )
    
    ax.set_title(f"{window} hrs", fontsize=11, weight="bold")
    ax.set_xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.0f}%)", fontsize=9)
    ax.set_ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.0f}%)", fontsize=9)
    ax.legend(fontsize=7, loc='best')
    ax.grid(alpha=0.3)

# Hide unused subplots
for idx in range(n_windows, len(axes)):
    axes[idx].set_visible(False)

plt.suptitle("GMM ICU Phenotypes Across Time Windows", 
             fontsize=16, weight="bold", y=0.995)
plt.tight_layout()

combined_plot_path = "phenotype_plots/combined_cluster_plots.png"
plt.savefig(combined_plot_path, dpi=300, bbox_inches='tight')
print(f"Saved combined plot to: {combined_plot_path}")
plt.close()

print("\n" + "="*60)
print("Processing complete!")
print(f"Individual plots: phenotype_plots/cluster_plot_*hrs.png")
print(f"Combined plot: {combined_plot_path}")
print("="*60)
# Out:
# ============================================================
# Processing window: 0_6 hrs
# ============================================================
# Original data: 512637 rows, 65017 patients
#   Filtered 1028 rows with abnormal fio2_mean values
#   Filtered 4214 rows with abnormal peep_mean values
#   Filtered 458 rows with abnormal peak_mean values
#   Filtered 100247 rows with abnormal pao2_mean values
#   Filtered 196 rows with abnormal spo2_mean values
#   Filtered 810 rows with abnormal ph_mean values
#   Filtered 225 rows with abnormal crp_mean values
#   Filtered 512 rows with abnormal wbc_mean values
#   Filtered 25546 rows with abnormal temp_mean values
#   Filtered 13826 rows with abnormal map_mean values
#   Filtered 1975 rows with abnormal sbp_mean values
#   Filtered 129 rows with abnormal dbp_mean values
#   Filtered 266 rows with abnormal creatinine_mean values
#   Filtered 251 rows with abnormal platelets_mean values
# After filtering: 362954 rows (70.8%), 62378 patients
# Patient-level data: 62378 patients
# Missing values before imputation: 462129
#
# Phenotype distribution:
#   Phenotype 0: 4812 patients (7.7%)
#   Phenotype 1: 57566 patients (92.3%)
# Saved summary to: phenotype_summaries/phenotype_summary_0_6hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_0_6hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         63.982656   49.177442
# peep_mean          9.384888    7.179477
# peak_mean         30.949150         NaN
# pao2_mean         93.516906         NaN
# spo2_mean         91.923919   94.825164
# ph_mean            7.293037    7.331388
# crp_mean         176.944020   40.953126
# wbc_mean          16.008190   13.729766
# temp_mean         37.191362   36.726603
# map_mean          68.631491   70.747399
# sbp_mean          99.612626  102.736755
# dbp_mean          61.498277   63.090536
# creatinine_mean  226.620939   88.846324
# platelets_mean   226.683887  185.396907
# age               62.230466   61.543724
#
# ============================================================
# Processing window: 6_12 hrs
# ============================================================
# Original data: 423053 rows, 63202 patients
#   Filtered 855 rows with abnormal fio2_mean values
#   Filtered 2430 rows with abnormal peep_mean values
#   Filtered 118 rows with abnormal peak_mean values
#   Filtered 57487 rows with abnormal pao2_mean values
#   Filtered 121 rows with abnormal spo2_mean values
#   Filtered 227 rows with abnormal ph_mean values
#   Filtered 107 rows with abnormal crp_mean values
#   Filtered 209 rows with abnormal wbc_mean values
#   Filtered 21979 rows with abnormal temp_mean values
#   Filtered 7733 rows with abnormal map_mean values
#   Filtered 1467 rows with abnormal sbp_mean values
#   Filtered 60 rows with abnormal dbp_mean values
#   Filtered 103 rows with abnormal creatinine_mean values
#   Filtered 105 rows with abnormal platelets_mean values
# After filtering: 330052 rows (78.0%), 60218 patients
# Patient-level data: 60218 patients
# Missing values before imputation: 515211
#
# Phenotype distribution:
#   Phenotype 0: 4393 patients (7.3%)
#   Phenotype 1: 55825 patients (92.7%)
# Saved summary to: phenotype_summaries/phenotype_summary_6_12hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_6_12hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         56.720784   43.618601
# peep_mean          9.922722    7.151333
# peak_mean         27.607059         NaN
# pao2_mean        101.280057         NaN
# spo2_mean         91.860804   94.859308
# ph_mean            7.318508    7.363228
# crp_mean         148.511317   46.304938
# wbc_mean          15.987843   11.983753
# temp_mean         37.042669   36.969992
# map_mean          70.534561   72.954284
# sbp_mean         102.381227  106.955890
# dbp_mean          62.673293   64.690549
# creatinine_mean  191.171100   86.094229
# platelets_mean   239.032777  181.444694
# age               61.998407   61.593999
#
# ============================================================
# Processing window: 12_18 hrs
# ============================================================
# Original data: 396464 rows, 60651 patients
#   Filtered 775 rows with abnormal fio2_mean values
#   Filtered 1983 rows with abnormal peep_mean values
#   Filtered 116 rows with abnormal peak_mean values
#   Filtered 48148 rows with abnormal pao2_mean values
#   Filtered 119 rows with abnormal spo2_mean values
#   Filtered 162 rows with abnormal ph_mean values
#   Filtered 110 rows with abnormal crp_mean values
#   Filtered 192 rows with abnormal wbc_mean values
#   Filtered 19999 rows with abnormal temp_mean values
#   Filtered 7407 rows with abnormal map_mean values
#   Filtered 1278 rows with abnormal sbp_mean values
#   Filtered 50 rows with abnormal dbp_mean values
#   Filtered 89 rows with abnormal creatinine_mean values
#   Filtered 109 rows with abnormal platelets_mean values
# After filtering: 315927 rows (79.7%), 58133 patients
# Patient-level data: 58133 patients
# Missing values before imputation: 496282
#
# Phenotype distribution:
#   Phenotype 0: 24224 patients (41.7%)
#   Phenotype 1: 33909 patients (58.3%)
# Saved summary to: phenotype_summaries/phenotype_summary_12_18hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_12_18hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         49.067798   42.090043
# peep_mean          8.329083    7.170112
# peak_mean         28.982636   25.032370
# pao2_mean         95.227103   94.844482
# spo2_mean         94.172552   94.455125
# ph_mean            7.366374    7.378824
# crp_mean          85.848047   70.745652
# wbc_mean          13.432964   12.818662
# temp_mean         36.934040   36.911443
# map_mean          72.767936   74.430857
# sbp_mean         108.010275  109.650367
# dbp_mean          64.088125   65.976196
# creatinine_mean  102.190071  102.086801
# platelets_mean   190.175475  173.347050
# age               62.715571   61.231797
#
# ============================================================
# Processing window: 18_24 hrs
# ============================================================
# Original data: 324552 rows, 54018 patients
#   Filtered 722 rows with abnormal fio2_mean values
#   Filtered 1646 rows with abnormal peep_mean values
#   Filtered 77 rows with abnormal peak_mean values
#   Filtered 36348 rows with abnormal pao2_mean values
#   Filtered 116 rows with abnormal spo2_mean values
#   Filtered 135 rows with abnormal ph_mean values
#   Filtered 74 rows with abnormal crp_mean values
#   Filtered 99 rows with abnormal wbc_mean values
#   Filtered 16675 rows with abnormal temp_mean values
#   Filtered 6849 rows with abnormal map_mean values
#   Filtered 1133 rows with abnormal sbp_mean values
#   Filtered 49 rows with abnormal dbp_mean values
#   Filtered 35 rows with abnormal creatinine_mean values
#   Filtered 54 rows with abnormal platelets_mean values
# After filtering: 260540 rows (80.3%), 51874 patients
# Patient-level data: 51874 patients
# Missing values before imputation: 497207
#
# Phenotype distribution:
#   Phenotype 0: 44704 patients (86.2%)
#   Phenotype 1: 7170 patients (13.8%)
# Saved summary to: phenotype_summaries/phenotype_summary_18_24hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_18_24hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         44.413491   51.305716
# peep_mean          7.658932    9.157721
# peak_mean               NaN   29.285431
# pao2_mean               NaN   89.789863
# spo2_mean         94.203489   94.102422
# ph_mean            7.381041    7.356679
# crp_mean                NaN  127.303490
# wbc_mean                NaN   13.467629
# temp_mean         36.952633   36.875606
# map_mean          74.723718   73.280133
# sbp_mean         111.444600  108.706268
# dbp_mean          66.006045   64.378879
# creatinine_mean  123.000006  123.143658
# platelets_mean          NaN  183.498103
# age               62.172714   62.122873
#
# ============================================================
# Processing window: 24_30 hrs
# ============================================================
# Original data: 258083 rows, 40171 patients
#   Filtered 678 rows with abnormal fio2_mean values
#   Filtered 1293 rows with abnormal peep_mean values
#   Filtered 43 rows with abnormal peak_mean values
#   Filtered 30507 rows with abnormal pao2_mean values
#   Filtered 78 rows with abnormal spo2_mean values
#   Filtered 77 rows with abnormal ph_mean values
#   Filtered 99 rows with abnormal crp_mean values
#   Filtered 102 rows with abnormal wbc_mean values
#   Filtered 15082 rows with abnormal temp_mean values
#   Filtered 5892 rows with abnormal map_mean values
#   Filtered 925 rows with abnormal sbp_mean values
#   Filtered 47 rows with abnormal dbp_mean values
#   Filtered 30 rows with abnormal creatinine_mean values
#   Filtered 82 rows with abnormal platelets_mean values
# After filtering: 203148 rows (78.7%), 38132 patients
# Patient-level data: 38132 patients
# Missing values before imputation: 354827
#
# Phenotype distribution:
#   Phenotype 0: 31991 patients (83.9%)
#   Phenotype 1: 6141 patients (16.1%)
# Saved summary to: phenotype_summaries/phenotype_summary_24_30hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_24_30hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         45.141554   49.594775
# peep_mean          7.918065    8.975652
# peak_mean               NaN   29.087744
# pao2_mean               NaN   88.963242
# spo2_mean         93.953981   93.858085
# ph_mean            7.376359    7.359375
# crp_mean                NaN  143.644927
# wbc_mean                NaN   13.156445
# temp_mean         36.988348   36.929116
# map_mean          73.857890   72.726667
# sbp_mean         110.083771  107.303153
# dbp_mean          65.121759   64.095519
# creatinine_mean  125.000006  125.315563
# platelets_mean          NaN  185.032792
# age               62.000907   60.445367
#
# ============================================================
# Processing window: 30_36 hrs
# ============================================================
# Original data: 241743 rows, 36780 patients
#   Filtered 511 rows with abnormal fio2_mean values
#   Filtered 1135 rows with abnormal peep_mean values
#   Filtered 15 rows with abnormal peak_mean values
#   Filtered 27788 rows with abnormal pao2_mean values
#   Filtered 52 rows with abnormal spo2_mean values
#   Filtered 77 rows with abnormal ph_mean values
#   Filtered 128 rows with abnormal crp_mean values
#   Filtered 102 rows with abnormal wbc_mean values
#   Filtered 13707 rows with abnormal temp_mean values
#   Filtered 5830 rows with abnormal map_mean values
#   Filtered 820 rows with abnormal sbp_mean values
#   Filtered 47 rows with abnormal dbp_mean values
#   Filtered 45 rows with abnormal creatinine_mean values
#   Filtered 85 rows with abnormal platelets_mean values
# After filtering: 191401 rows (79.2%), 34989 patients
# Patient-level data: 34989 patients
# Missing values before imputation: 311320
#
# Phenotype distribution:
#   Phenotype 0: 17958 patients (51.3%)
#   Phenotype 1: 17031 patients (48.7%)
# Saved summary to: phenotype_summaries/phenotype_summary_30_36hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_30_36hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         46.828805   44.589531
# peep_mean          8.487862    7.617239
# peak_mean         34.494949   28.524809
# pao2_mean               NaN   92.742899
# spo2_mean         93.402015   94.375073
# ph_mean            7.373164    7.375262
# crp_mean         141.364849  162.794445
# wbc_mean          13.573730   12.910345
# temp_mean         36.925890   36.901890
# map_mean          72.909008   74.477229
# sbp_mean         108.441939  110.604832
# dbp_mean          64.113154   65.702126
# creatinine_mean  116.176879  129.922481
# platelets_mean   183.562598  155.784091
# age               61.935795   61.371675
#
# ============================================================
# Processing window: 36_42 hrs
# ============================================================
# Original data: 225836 rows, 34893 patients
#   Filtered 474 rows with abnormal fio2_mean values
#   Filtered 980 rows with abnormal peep_mean values
#   Filtered 21 rows with abnormal peak_mean values
#   Filtered 26146 rows with abnormal pao2_mean values
#   Filtered 56 rows with abnormal spo2_mean values
#   Filtered 38 rows with abnormal ph_mean values
#   Filtered 114 rows with abnormal crp_mean values
#   Filtered 129 rows with abnormal wbc_mean values
#   Filtered 11645 rows with abnormal temp_mean values
#   Filtered 5585 rows with abnormal map_mean values
#   Filtered 835 rows with abnormal sbp_mean values
#   Filtered 46 rows with abnormal dbp_mean values
#   Filtered 32 rows with abnormal creatinine_mean values
#   Filtered 102 rows with abnormal platelets_mean values
# After filtering: 179633 rows (79.5%), 33396 patients
# Patient-level data: 33396 patients
# Missing values before imputation: 290899
#
# Phenotype distribution:
#   Phenotype 0: 1769 patients (5.3%)
#   Phenotype 1: 31627 patients (94.7%)
# Saved summary to: phenotype_summaries/phenotype_summary_36_42hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_36_42hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         54.296050   46.297595
# peep_mean         10.165075    8.126756
# peak_mean         29.095310         NaN
# pao2_mean         89.754112         NaN
# spo2_mean         93.395508   93.823748
# ph_mean            7.337321    7.382941
# crp_mean         206.032154  110.495664
# wbc_mean          17.371496   13.204887
# temp_mean         37.112032   36.888591
# map_mean          71.687792   74.683389
# sbp_mean         106.368657  111.103960
# dbp_mean          62.991091   65.769410
# creatinine_mean  217.912542   90.762557
# platelets_mean   241.622207  161.893496
# age               62.684002   61.839283
#
# ============================================================
# Processing window: 42_48 hrs
# ============================================================
# Original data: 196519 rows, 31624 patients
#   Filtered 392 rows with abnormal fio2_mean values
#   Filtered 824 rows with abnormal peep_mean values
#   Filtered 18 rows with abnormal peak_mean values
#   Filtered 21684 rows with abnormal pao2_mean values
#   Filtered 84 rows with abnormal spo2_mean values
#   Filtered 22 rows with abnormal ph_mean values
#   Filtered 50 rows with abnormal crp_mean values
#   Filtered 69 rows with abnormal wbc_mean values
#   Filtered 9949 rows with abnormal temp_mean values
#   Filtered 5348 rows with abnormal map_mean values
#   Filtered 712 rows with abnormal sbp_mean values
#   Filtered 32 rows with abnormal dbp_mean values
#   Filtered 18 rows with abnormal creatinine_mean values
#   Filtered 49 rows with abnormal platelets_mean values
# After filtering: 157268 rows (80.0%), 30328 patients
# Patient-level data: 30328 patients
# Missing values before imputation: 285457
#
# Phenotype distribution:
#   Phenotype 0: 3776 patients (12.5%)
#   Phenotype 1: 26552 patients (87.5%)
# Saved summary to: phenotype_summaries/phenotype_summary_42_48hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_42_48hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         50.734478   47.013293
# peep_mean          9.411334    8.160667
# peak_mean         29.522166         NaN
# pao2_mean         92.315238         NaN
# spo2_mean         93.571151   93.874676
# ph_mean            7.363299    7.380507
# crp_mean         147.213172         NaN
# wbc_mean          13.799530   13.799999
# temp_mean         36.911808   36.998381
# map_mean          73.391611   75.274888
# sbp_mean         109.586209  112.346374
# dbp_mean          64.410557   66.315609
# creatinine_mean  130.277152  130.000001
# platelets_mean   175.856096         NaN
# age               61.409428   62.002900
#
# ============================================================
# Processing window: 48_54 hrs
# ============================================================
# Original data: 173818 rows, 26886 patients
#   Filtered 336 rows with abnormal fio2_mean values
#   Filtered 687 rows with abnormal peep_mean values
#   Filtered 12 rows with abnormal peak_mean values
#   Filtered 19601 rows with abnormal pao2_mean values
#   Filtered 67 rows with abnormal spo2_mean values
#   Filtered 20 rows with abnormal ph_mean values
#   Filtered 63 rows with abnormal crp_mean values
#   Filtered 70 rows with abnormal wbc_mean values
#   Filtered 9211 rows with abnormal temp_mean values
#   Filtered 4823 rows with abnormal map_mean values
#   Filtered 640 rows with abnormal sbp_mean values
#   Filtered 22 rows with abnormal dbp_mean values
#   Filtered 16 rows with abnormal creatinine_mean values
#   Filtered 76 rows with abnormal platelets_mean values
# After filtering: 138174 rows (79.5%), 25579 patients
# Patient-level data: 25579 patients
# Missing values before imputation: 233047
#
# Phenotype distribution:
#   Phenotype 0: 3962 patients (15.5%)
#   Phenotype 1: 21617 patients (84.5%)
# Saved summary to: phenotype_summaries/phenotype_summary_48_54hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_48_54hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         49.369998   46.756889
# peep_mean          9.262268    8.229745
# peak_mean         28.617340         NaN
# pao2_mean         92.542501         NaN
# spo2_mean         93.701080   93.760923
# ph_mean            7.372412    7.383285
# crp_mean         150.059675         NaN
# wbc_mean          13.308502         NaN
# temp_mean         36.908260   37.056395
# map_mean          74.390120   75.156715
# sbp_mean         110.826076  112.151650
# dbp_mean          65.366736   66.134774
# creatinine_mean  126.279195         NaN
# platelets_mean   179.408046         NaN
# age               60.864967   61.798908
#
# ============================================================
# Processing window: 54_60 hrs
# ============================================================
# Original data: 165844 rows, 25409 patients
#   Filtered 324 rows with abnormal fio2_mean values
#   Filtered 595 rows with abnormal peep_mean values
#   Filtered 11 rows with abnormal peak_mean values
#   Filtered 18697 rows with abnormal pao2_mean values
#   Filtered 52 rows with abnormal spo2_mean values
#   Filtered 11 rows with abnormal ph_mean values
#   Filtered 91 rows with abnormal crp_mean values
#   Filtered 85 rows with abnormal wbc_mean values
#   Filtered 8729 rows with abnormal temp_mean values
#   Filtered 4817 rows with abnormal map_mean values
#   Filtered 617 rows with abnormal sbp_mean values
#   Filtered 24 rows with abnormal dbp_mean values
#   Filtered 30 rows with abnormal creatinine_mean values
#   Filtered 92 rows with abnormal platelets_mean values
# After filtering: 131669 rows (79.4%), 24176 patients
# Patient-level data: 24176 patients
# Missing values before imputation: 211629
#
# Phenotype distribution:
#   Phenotype 0: 5704 patients (23.6%)
#   Phenotype 1: 18472 patients (76.4%)
# Saved summary to: phenotype_summaries/phenotype_summary_54_60hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_54_60hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         48.698906   46.698514
# peep_mean          9.051704    8.204698
# peak_mean         28.605664         NaN
# pao2_mean         93.106044         NaN
# spo2_mean         93.596938   93.764722
# ph_mean            7.385100    7.385652
# crp_mean         146.486612         NaN
# wbc_mean          13.137892         NaN
# temp_mean         36.935719   37.023532
# map_mean          74.224606   75.633646
# sbp_mean         110.974618  112.632442
# dbp_mean          65.180841   66.568264
# creatinine_mean  116.340067  116.000003
# platelets_mean   182.234016         NaN
# age               62.301718   61.469955
#
# ============================================================
# Processing window: 60_66 hrs
# ============================================================
# Original data: 157277 rows, 24401 patients
#   Filtered 314 rows with abnormal fio2_mean values
#   Filtered 622 rows with abnormal peep_mean values
#   Filtered 11 rows with abnormal peak_mean values
#   Filtered 17437 rows with abnormal pao2_mean values
#   Filtered 48 rows with abnormal spo2_mean values
#   Filtered 20 rows with abnormal ph_mean values
#   Filtered 68 rows with abnormal crp_mean values
#   Filtered 79 rows with abnormal wbc_mean values
#   Filtered 7995 rows with abnormal temp_mean values
#   Filtered 4772 rows with abnormal map_mean values
#   Filtered 613 rows with abnormal sbp_mean values
#   Filtered 28 rows with abnormal dbp_mean values
#   Filtered 29 rows with abnormal creatinine_mean values
#   Filtered 94 rows with abnormal platelets_mean values
# After filtering: 125147 rows (79.6%), 23308 patients
# Patient-level data: 23308 patients
# Missing values before imputation: 201806
#
# Phenotype distribution:
#   Phenotype 0: 1530 patients (6.6%)
#   Phenotype 1: 21778 patients (93.4%)
# Saved summary to: phenotype_summaries/phenotype_summary_60_66hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_60_66hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         53.739477   46.504431
# peep_mean         10.213721    8.286217
# peak_mean         28.995168   29.000000
# pao2_mean         93.487864         NaN
# spo2_mean         90.639586   94.009849
# ph_mean            7.354911    7.395006
# crp_mean         183.955593  122.353221
# wbc_mean          18.192125   11.760846
# temp_mean         36.949009   36.962757
# map_mean          73.401293   76.353121
# sbp_mean         110.500684  113.962802
# dbp_mean          64.356228   67.154831
# creatinine_mean  207.569188   89.920245
# platelets_mean   234.803105  163.176024
# age               62.992810   61.728625
#
# ============================================================
# Processing window: 66_72 hrs
# ============================================================
# Original data: 120419 rows, 22726 patients
#   Filtered 236 rows with abnormal fio2_mean values
#   Filtered 464 rows with abnormal peep_mean values
#   Filtered 9 rows with abnormal peak_mean values
#   Filtered 13092 rows with abnormal pao2_mean values
#   Filtered 64 rows with abnormal spo2_mean values
#   Filtered 10 rows with abnormal ph_mean values
#   Filtered 28 rows with abnormal crp_mean values
#   Filtered 41 rows with abnormal wbc_mean values
#   Filtered 6129 rows with abnormal temp_mean values
#   Filtered 4036 rows with abnormal map_mean values
#   Filtered 518 rows with abnormal sbp_mean values
#   Filtered 24 rows with abnormal dbp_mean values
#   Filtered 10 rows with abnormal creatinine_mean values
#   Filtered 57 rows with abnormal platelets_mean values
# After filtering: 95701 rows (79.5%), 21597 patients
# Patient-level data: 21597 patients
# Missing values before imputation: 200729
#
# Phenotype distribution:
#   Phenotype 0: 2378 patients (11.0%)
#   Phenotype 1: 19219 patients (89.0%)
# Saved summary to: phenotype_summaries/phenotype_summary_66_72hrs.csv
# Saved plot to: phenotype_plots/cluster_plot_66_72hrs.png
#
# Phenotype Summary:
# icu_phenotype             0           1
# fio2_mean         49.557842   46.978897
# peep_mean          9.584719    8.241840
# peak_mean         29.230649         NaN
# pao2_mean         94.267531         NaN
# spo2_mean         93.761121   93.959845
# ph_mean            7.382893    7.395699
# crp_mean         134.242380         NaN
# wbc_mean          13.532438         NaN
# temp_mean         36.805823   36.971828
# map_mean          75.814254   77.861274
# sbp_mean         114.074166  116.691479
# dbp_mean          66.364113   68.444200
# creatinine_mean  131.880880  132.000001
# platelets_mean   179.946746         NaN
# age               61.693860   61.799053
#
# ============================================================
# Data quality summary saved to: phenotype_summaries/data_quality_summary.csv
# Combined summary saved to: phenotype_summaries/all_phenotypes_combined.csv
#
# Creating combined plot with all time windows...
# Saved combined plot to: phenotype_plots/combined_cluster_plots.png
#
# ============================================================
# Processing complete!
# Individual plots: phenotype_plots/cluster_plot_*hrs.png
# Combined plot: phenotype_plots/combined_cluster_plots.png
# ============================================================
